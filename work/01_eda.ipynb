# %% [markdown]
# # EDA: Ranking Signal Analysis
# This notebook performs exploratory data analysis on the FlyRank dataset (see setup).

# %%
# Example: access HF-hosted DuckDB dataset using environment token
import os
import duckdb
# set HF token in env as HUGGINGFACE_TOKEN before running
hf_token = os.environ.get('HUGGINGFACE_TOKEN')
print('HUGGINGFACE_TOKEN set:', bool(hf_token))
# Example query (replace with actual hf:// path from FlyRank instructions)
# con = duckdb.connect()
# con.execute(f

,

)
# df = con.execute(
