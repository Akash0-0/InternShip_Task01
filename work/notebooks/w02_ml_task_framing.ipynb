# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Akash0-0/InternShip_Task01/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# Lane 1 – Ranking Signal Analysis
# This project is primarily a ranking and scoring problem, with classification used as an optional supporting technique.
# The objective is not simply to classify pages as "good" or "bad." Instead, the goal is to identify which content pages deserve
# the highest priority for human review by analyzing observable search and engagement signals.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# The starter dataset does not contain future performance labels, so a proxy target is required.
# For the starter project, the proxy target is:
# trend_direction == "down"
import pandas as pd

# Load the starter dataset
df = pd.read_csv("/content_refresh_anonymized.csv")
# Create the proxy target
df["is_declining_label"] = (df["trend_direction"] == "down").astype(int)

# Check the new target
df[["trend_direction", "is_declining_label"]].head()

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# Precision@K – Measures how many of the top-ranked pages actually require review.
# ROC-AUC – Measures the model's ability to distinguish between declining and non-declining pages.
# Recall – Ensures important pages are not missed.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
print(f"Rows: {df.shape[0]}")
print(f"Columns: {df.shape[1]}")

# Display the first few rows
print("One Row = One Unit")
df[100]

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# Machine learning can simultaneously evaluate dozens of interacting signals

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
